# %% [markdown]
# <a href="https://colab.research.google.com/github/VolM-IVT110/Lyuboe/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive') 
import os 
os.chdir('/content/drive/MyDrive/Colab Notebooks') 
from tensorflow import keras 
import matplotlib.pyplot as plt 
import numpy as np 
import sklearn 
from keras.datasets import mnist 
(X_train, y_train), (X_test, y_test) = mnist.load_data() 
from sklearn.model_selection import train_test_split 
X = np.concatenate((X_train, X_test)) 
y = np.concatenate((y_train, y_test)) 
X_train, X_test, y_train, y_test = train_test_split(X, y, 
test_size = 10000, 
train_size = 60000, 
random_state = 123) 
print('Shape of X train:', X_train.shape) 
print('Shape of y train:', y_train.shape) 
plt.imshow(X_train[123], cmap=plt.get_cmap('gray')) 
plt.show() 
print(y_train[123]) 
num_pixels = X_train.shape[1] * X_train.shape[2] 
X_train = X_train.reshape(X_train.shape[0], num_pixels) / 255 
X_test = X_test.reshape(X_test.shape[0], num_pixels) / 255 
print('Shape of transformed X train:', X_train.shape) 
from keras.utils import np_utils 
y_train = np_utils.to_categorical(y_train) 
y_test = np_utils.to_categorical(y_test) 
print('Shape of transformed y train:', y_train.shape) 
num_classes = y_train.shape[1] 
from keras.models import Sequential 
from keras.layers import Dense 
# 1. создаем модель - объявляем ее объектом класса Sequential 
model = Sequential() 
# 2. добавляем первый скрытый слой 
model.add(Dense(units=300, input_dim=num_pixels, activation='sigmoid')) 
# 3. добавляем второй скрытый слой 
model.add(Dense(units=100, activation='sigmoid')) 
# 4. добавляем выходной слой 
model.add(Dense(units=num_classes, activation='softmax')) 
# 5. компилируем модель 
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) 
print(model.summary()) 
H = model.fit(X_train, y_train, validation_split=0.1, epochs=100) 
plt.plot(H.history['loss']) 
plt.plot(H.history['val_loss']) 
plt.grid() 
plt.xlabel('Epochs') 
plt.ylabel('loss') 
plt.legend(['train_loss', 'val_loss']) 
plt.title('Loss by epochs') 
plt.show() 
scores = model.evaluate(X_test, y_test) 
print('Loss on test data:', scores[0]) 
print('Accuracy on test data:', scores[1]) 
n = 123 
result = model.predict(X_test[n:n+1]) 
print('NN output:', result) 
plt.imshow(X_test[n].reshape(28,28), cmap=plt.get_cmap('gray')) 
plt.show() 
print('Real mark: ', str(np.argmax(y_test[n]))) 
print('NN answer: ', str(np.argmax(result))) 
from PIL import Image 
file_data = Image.open('test.png') 
file_data = file_data.convert('L') # перевод в градации серого 
test_img = np.array(file_data) 
# вывод собственного изображения 
plt.imshow(test_img, cmap=plt.get_cmap('gray')) 
plt.show() 
# предобработка 
test_img = test_img / 255 
test_img = test_img.reshape(1, num_pixels) 
# распознавание 
result = model.predict(test_img) 
print('I think it\'s ', np.argmax(result))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Shape of X train: (60000, 28, 28)
# Shape of y train: (60000,)
# 4
# Shape of transformed X train: (60000, 784)
# Shape of transformed y train: (60000, 10)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 2.1539 - accuracy: 0.3890 - val_loss: 1.9317 - val_accuracy: 0.6223
# Epoch 2/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 1.5645 - accuracy: 0.6671 - val_loss: 1.2048 - val_accuracy: 0.7477
# Epoch 3/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.9714 - accuracy: 0.7896 - val_loss: 0.8002 - val_accuracy: 0.8210
# Epoch 4/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.6967 - accuracy: 0.8399 - val_loss: 0.6189 - val_accuracy: 0.8517
# Epoch 5/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.5636 - accuracy: 0.8609 - val_loss: 0.5231 - val_accuracy: 0.8678
# Epoch 6/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.4897 - accuracy: 0.8749 - val_loss: 0.4679 - val_accuracy: 0.8777
# Epoch 7/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.4442 - accuracy: 0.8816 - val_loss: 0.4308 - val_accuracy: 0.8880
# Epoch 8/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.4138 - accuracy: 0.8879 - val_loss: 0.4060 - val_accuracy: 0.8920
# Epoch 9/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3918 - accuracy: 0.8924 - val_loss: 0.3886 - val_accuracy: 0.8942
# Epoch 10/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3750 - accuracy: 0.8954 - val_loss: 0.3730 - val_accuracy: 0.8972
# Epoch 11/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3617 - accuracy: 0.8982 - val_loss: 0.3625 - val_accuracy: 0.8998
# Epoch 12/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3506 - accuracy: 0.9007 - val_loss: 0.3521 - val_accuracy: 0.9010
# Epoch 13/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3411 - accuracy: 0.9030 - val_loss: 0.3443 - val_accuracy: 0.9047
# Epoch 14/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3328 - accuracy: 0.9052 - val_loss: 0.3373 - val_accuracy: 0.9043
# Epoch 15/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3257 - accuracy: 0.9060 - val_loss: 0.3296 - val_accuracy: 0.9068
# Epoch 16/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3192 - accuracy: 0.9084 - val_loss: 0.3237 - val_accuracy: 0.9083
# Epoch 17/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3134 - accuracy: 0.9098 - val_loss: 0.3188 - val_accuracy: 0.9103
# Epoch 18/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.3078 - accuracy: 0.9112 - val_loss: 0.3133 - val_accuracy: 0.9107
# Epoch 19/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.3027 - accuracy: 0.9128 - val_loss: 0.3083 - val_accuracy: 0.9143
# Epoch 20/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2981 - accuracy: 0.9141 - val_loss: 0.3043 - val_accuracy: 0.9132
# Epoch 21/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2937 - accuracy: 0.9147 - val_loss: 0.3010 - val_accuracy: 0.9148
# Epoch 22/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2897 - accuracy: 0.9168 - val_loss: 0.2969 - val_accuracy: 0.9153
# Epoch 23/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2859 - accuracy: 0.9172 - val_loss: 0.2936 - val_accuracy: 0.9162
# Epoch 24/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2821 - accuracy: 0.9188 - val_loss: 0.2911 - val_accuracy: 0.9173
# Epoch 25/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2786 - accuracy: 0.9195 - val_loss: 0.2867 - val_accuracy: 0.9188
# Epoch 26/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2752 - accuracy: 0.9204 - val_loss: 0.2835 - val_accuracy: 0.9217
# Epoch 27/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2720 - accuracy: 0.9216 - val_loss: 0.2816 - val_accuracy: 0.9212
# Epoch 28/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2688 - accuracy: 0.9221 - val_loss: 0.2781 - val_accuracy: 0.9203
# Epoch 29/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2657 - accuracy: 0.9235 - val_loss: 0.2742 - val_accuracy: 0.9233
# Epoch 30/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2625 - accuracy: 0.9243 - val_loss: 0.2719 - val_accuracy: 0.9235
# Epoch 31/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2598 - accuracy: 0.9248 - val_loss: 0.2702 - val_accuracy: 0.9235
# Epoch 32/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2569 - accuracy: 0.9262 - val_loss: 0.2672 - val_accuracy: 0.9228
# Epoch 33/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2542 - accuracy: 0.9263 - val_loss: 0.2653 - val_accuracy: 0.9238
# Epoch 34/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2515 - accuracy: 0.9271 - val_loss: 0.2618 - val_accuracy: 0.9247
# Epoch 35/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2488 - accuracy: 0.9279 - val_loss: 0.2586 - val_accuracy: 0.9253
# Epoch 36/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2464 - accuracy: 0.9286 - val_loss: 0.2564 - val_accuracy: 0.9255
# Epoch 37/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2438 - accuracy: 0.9292 - val_loss: 0.2542 - val_accuracy: 0.9253
# Epoch 38/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2412 - accuracy: 0.9304 - val_loss: 0.2522 - val_accuracy: 0.9270
# Epoch 39/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2387 - accuracy: 0.9307 - val_loss: 0.2511 - val_accuracy: 0.9273
# Epoch 40/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2362 - accuracy: 0.9313 - val_loss: 0.2490 - val_accuracy: 0.9292
# Epoch 41/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2338 - accuracy: 0.9324 - val_loss: 0.2449 - val_accuracy: 0.9303
# Epoch 42/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2314 - accuracy: 0.9324 - val_loss: 0.2436 - val_accuracy: 0.9298
# Epoch 43/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2289 - accuracy: 0.9335 - val_loss: 0.2418 - val_accuracy: 0.9308
# Epoch 44/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2266 - accuracy: 0.9346 - val_loss: 0.2388 - val_accuracy: 0.9303
# Epoch 45/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2244 - accuracy: 0.9351 - val_loss: 0.2363 - val_accuracy: 0.9310
# Epoch 46/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2221 - accuracy: 0.9359 - val_loss: 0.2367 - val_accuracy: 0.9317
# Epoch 47/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2200 - accuracy: 0.9360 - val_loss: 0.2320 - val_accuracy: 0.9330
# Epoch 48/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2178 - accuracy: 0.9371 - val_loss: 0.2305 - val_accuracy: 0.9327
# Epoch 49/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.2154 - accuracy: 0.9374 - val_loss: 0.2286 - val_accuracy: 0.9342
# Epoch 50/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2132 - accuracy: 0.9379 - val_loss: 0.2264 - val_accuracy: 0.9348
# Epoch 51/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2111 - accuracy: 0.9387 - val_loss: 0.2244 - val_accuracy: 0.9343
# Epoch 52/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2090 - accuracy: 0.9393 - val_loss: 0.2227 - val_accuracy: 0.9355
# Epoch 53/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2068 - accuracy: 0.9400 - val_loss: 0.2218 - val_accuracy: 0.9352
# Epoch 54/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2047 - accuracy: 0.9404 - val_loss: 0.2187 - val_accuracy: 0.9362
# Epoch 55/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2027 - accuracy: 0.9412 - val_loss: 0.2186 - val_accuracy: 0.9372
# Epoch 56/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2007 - accuracy: 0.9419 - val_loss: 0.2168 - val_accuracy: 0.9363
# Epoch 57/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1987 - accuracy: 0.9424 - val_loss: 0.2133 - val_accuracy: 0.9378
# Epoch 58/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1967 - accuracy: 0.9432 - val_loss: 0.2121 - val_accuracy: 0.9382
# Epoch 59/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1947 - accuracy: 0.9436 - val_loss: 0.2096 - val_accuracy: 0.9377
# Epoch 60/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1927 - accuracy: 0.9442 - val_loss: 0.2095 - val_accuracy: 0.9387
# Epoch 61/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1910 - accuracy: 0.9448 - val_loss: 0.2075 - val_accuracy: 0.9388
# Epoch 62/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1891 - accuracy: 0.9453 - val_loss: 0.2046 - val_accuracy: 0.9402
# Epoch 63/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1873 - accuracy: 0.9464 - val_loss: 0.2032 - val_accuracy: 0.9403
# Epoch 64/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1854 - accuracy: 0.9468 - val_loss: 0.2024 - val_accuracy: 0.9412
# Epoch 65/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1836 - accuracy: 0.9467 - val_loss: 0.1997 - val_accuracy: 0.9428
# Epoch 66/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1817 - accuracy: 0.9468 - val_loss: 0.1984 - val_accuracy: 0.9422
# Epoch 67/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1799 - accuracy: 0.9480 - val_loss: 0.1983 - val_accuracy: 0.9413
# Epoch 68/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1783 - accuracy: 0.9480 - val_loss: 0.1954 - val_accuracy: 0.9435
# Epoch 69/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1766 - accuracy: 0.9489 - val_loss: 0.1942 - val_accuracy: 0.9432
# Epoch 70/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1748 - accuracy: 0.9494 - val_loss: 0.1939 - val_accuracy: 0.9443
# Epoch 71/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1732 - accuracy: 0.9497 - val_loss: 0.1911 - val_accuracy: 0.9453
# Epoch 72/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1717 - accuracy: 0.9500 - val_loss: 0.1889 - val_accuracy: 0.9453
# Epoch 73/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1699 - accuracy: 0.9505 - val_loss: 0.1881 - val_accuracy: 0.9457
# Epoch 74/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1685 - accuracy: 0.9506 - val_loss: 0.1872 - val_accuracy: 0.9458
# Epoch 75/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1668 - accuracy: 0.9512 - val_loss: 0.1856 - val_accuracy: 0.9462
# Epoch 76/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1653 - accuracy: 0.9519 - val_loss: 0.1834 - val_accuracy: 0.9478
# Epoch 77/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1639 - accuracy: 0.9525 - val_loss: 0.1824 - val_accuracy: 0.9485
# Epoch 78/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1622 - accuracy: 0.9525 - val_loss: 0.1815 - val_accuracy: 0.9487
# Epoch 79/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1608 - accuracy: 0.9532 - val_loss: 0.1796 - val_accuracy: 0.9485
# Epoch 80/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1593 - accuracy: 0.9535 - val_loss: 0.1789 - val_accuracy: 0.9490
# Epoch 81/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1578 - accuracy: 0.9544 - val_loss: 0.1784 - val_accuracy: 0.9492
# Epoch 82/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1565 - accuracy: 0.9544 - val_loss: 0.1760 - val_accuracy: 0.9492
# Epoch 83/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1550 - accuracy: 0.9549 - val_loss: 0.1744 - val_accuracy: 0.9500
# Epoch 84/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1536 - accuracy: 0.9553 - val_loss: 0.1740 - val_accuracy: 0.9508
# Epoch 85/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1521 - accuracy: 0.9557 - val_loss: 0.1725 - val_accuracy: 0.9500
# Epoch 86/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1510 - accuracy: 0.9558 - val_loss: 0.1713 - val_accuracy: 0.9505
# Epoch 87/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1496 - accuracy: 0.9564 - val_loss: 0.1701 - val_accuracy: 0.9508
# Epoch 88/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1483 - accuracy: 0.9564 - val_loss: 0.1688 - val_accuracy: 0.9523
# Epoch 89/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1469 - accuracy: 0.9571 - val_loss: 0.1686 - val_accuracy: 0.9508
# Epoch 90/100
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.1455 - accuracy: 0.9578 - val_loss: 0.1670 - val_accuracy: 0.9512
# Epoch 91/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1443 - accuracy: 0.9586 - val_loss: 0.1665 - val_accuracy: 0.9513
# Epoch 92/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1431 - accuracy: 0.9582 - val_loss: 0.1647 - val_accuracy: 0.9515
# Epoch 93/100
# 1688/1688 [==============================] - 6s 3ms/step - loss: 0.1419 - accuracy: 0.9590 - val_loss: 0.1636 - val_accuracy: 0.9528
# Epoch 94/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1406 - accuracy: 0.9594 - val_loss: 0.1623 - val_accuracy: 0.9533
# Epoch 95/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1394 - accuracy: 0.9596 - val_loss: 0.1614 - val_accuracy: 0.9538
# Epoch 96/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1383 - accuracy: 0.9602 - val_loss: 0.1607 - val_accuracy: 0.9528
# Epoch 97/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1370 - accuracy: 0.9601 - val_loss: 0.1603 - val_accuracy: 0.9528
# Epoch 98/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1360 - accuracy: 0.9609 - val_loss: 0.1581 - val_accuracy: 0.9543
# Epoch 99/100
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.1347 - accuracy: 0.9611 - val_loss: 0.1579 - val_accuracy: 0.9535
# Epoch 100/100
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.1336 - accuracy: 0.9615 - val_loss: 0.1563 - val_accuracy: 0.9547
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1504 - accuracy: 0.9552
# Loss on test data: 0.15035516023635864
# Accuracy on test data: 0.9552000164985657
# 1/1 [==============================] - 0s 72ms/step
# NN output: [[1.35371703e-09 9.96728897e-01 6.42369050e-05 1.14986312e-03
#   1.82758540e-05 2.93475696e-05 1.31171491e-05 1.53504929e-03
#   1.17209056e-04 3.43973748e-04]]
# Real mark:  1
# NN answer:  1
# 1/1 [==============================] - 0s 20ms/step
# I think it's  6
